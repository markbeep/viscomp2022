# %% [markdown]
# # Week 5: PCA
#
# **The exercise of this week is about PCA. First load the following libraries that will be necessary.**

# %%
# !pip install scipy
# !pip install scikit-image
# !pip install matplotlib
# !unzip ./dataset.zip
# Out:
# Requirement already satisfied: scipy in /home/maak/.local/lib/python3.8/site-packages (1.7.2)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /home/maak/.local/lib/python3.8/site-packages (from scipy) (1.20.3)
# Requirement already satisfied: scikit-image in /home/maak/.local/lib/python3.8/site-packages (0.19.3)
# Requirement already satisfied: numpy>=1.17.0 in /home/maak/.local/lib/python3.8/site-packages (from scikit-image) (1.20.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/maak/.local/lib/python3.8/site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/maak/.local/lib/python3.8/site-packages (from scikit-image) (1.7.2)
# Requirement already satisfied: imageio>=2.4.1 in /home/maak/.local/lib/python3.8/site-packages (from scikit-image) (2.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from scikit-image) (20.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /home/maak/.local/lib/python3.8/site-packages (from scikit-image) (8.2.0)
# Requirement already satisfied: networkx>=2.2 in /home/maak/.local/lib/python3.8/site-packages (from scikit-image) (2.8.7)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/maak/.local/lib/python3.8/site-packages (from scikit-image) (2022.8.12)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (3.1.2)
# Archive:  ./dataset.zip
#    creating: dataset/
#   inflating: dataset/README
#    creating: dataset/s1/
#    creating: dataset/s10/
#   inflating: dataset/s10/1.pgm
#   inflating: dataset/s10/10.pgm
#   inflating: dataset/s10/2.pgm
#   inflating: dataset/s10/3.pgm
#   inflating: dataset/s10/4.pgm
#   inflating: dataset/s10/5.pgm
#   inflating: dataset/s10/6.pgm
#   inflating: dataset/s10/7.pgm
#   inflating: dataset/s10/8.pgm
#   inflating: dataset/s10/9.pgm
#    creating: dataset/s11/
#   inflating: dataset/s11/1.pgm
#   inflating: dataset/s11/10.pgm
#   inflating: dataset/s11/2.pgm
#   inflating: dataset/s11/3.pgm
#   inflating: dataset/s11/4.pgm
#   inflating: dataset/s11/5.pgm
#   inflating: dataset/s11/6.pgm
#   inflating: dataset/s11/7.pgm
#   inflating: dataset/s11/8.pgm
#   inflating: dataset/s11/9.pgm
#    creating: dataset/s12/
#   inflating: dataset/s12/1.pgm
#   inflating: dataset/s12/10.pgm
#   inflating: dataset/s12/2.pgm
#   inflating: dataset/s12/3.pgm
#   inflating: dataset/s12/4.pgm
#   inflating: dataset/s12/5.pgm
#   inflating: dataset/s12/6.pgm
#   inflating: dataset/s12/7.pgm
#   inflating: dataset/s12/8.pgm
#   inflating: dataset/s12/9.pgm
#    creating: dataset/s13/
#   inflating: dataset/s13/1.pgm
#   inflating: dataset/s13/10.pgm
#   inflating: dataset/s13/2.pgm
#   inflating: dataset/s13/3.pgm
#   inflating: dataset/s13/4.pgm
#   inflating: dataset/s13/5.pgm
#   inflating: dataset/s13/6.pgm
#   inflating: dataset/s13/7.pgm
#   inflating: dataset/s13/8.pgm
#   inflating: dataset/s13/9.pgm
#    creating: dataset/s14/
#   inflating: dataset/s14/1.pgm
#   inflating: dataset/s14/10.pgm
#   inflating: dataset/s14/2.pgm
#   inflating: dataset/s14/3.pgm
#   inflating: dataset/s14/4.pgm
#   inflating: dataset/s14/5.pgm
#   inflating: dataset/s14/6.pgm
#   inflating: dataset/s14/7.pgm
#   inflating: dataset/s14/8.pgm
#   inflating: dataset/s14/9.pgm
#    creating: dataset/s15/
#   inflating: dataset/s15/1.pgm
#   inflating: dataset/s15/10.pgm
#   inflating: dataset/s15/2.pgm
#   inflating: dataset/s15/3.pgm
#   inflating: dataset/s15/4.pgm
#   inflating: dataset/s15/5.pgm
#   inflating: dataset/s15/6.pgm
#   inflating: dataset/s15/7.pgm
#   inflating: dataset/s15/8.pgm
#   inflating: dataset/s15/9.pgm
#    creating: dataset/s16/
#   inflating: dataset/s16/1.pgm
#   inflating: dataset/s16/10.pgm
#   inflating: dataset/s16/2.pgm
#   inflating: dataset/s16/3.pgm
#   inflating: dataset/s16/4.pgm
#   inflating: dataset/s16/5.pgm
#   inflating: dataset/s16/6.pgm
#   inflating: dataset/s16/7.pgm
#   inflating: dataset/s16/8.pgm
#   inflating: dataset/s16/9.pgm
#    creating: dataset/s17/
#   inflating: dataset/s17/1.pgm
#   inflating: dataset/s17/10.pgm
#   inflating: dataset/s17/2.pgm
#   inflating: dataset/s17/3.pgm
#   inflating: dataset/s17/4.pgm
#   inflating: dataset/s17/5.pgm
#   inflating: dataset/s17/6.pgm
#   inflating: dataset/s17/7.pgm
#   inflating: dataset/s17/8.pgm
#   inflating: dataset/s17/9.pgm
#    creating: dataset/s18/
#   inflating: dataset/s18/1.pgm
#   inflating: dataset/s18/10.pgm
#   inflating: dataset/s18/2.pgm
#   inflating: dataset/s18/3.pgm
#   inflating: dataset/s18/4.pgm
#   inflating: dataset/s18/5.pgm
#   inflating: dataset/s18/6.pgm
#   inflating: dataset/s18/7.pgm
#   inflating: dataset/s18/8.pgm
#   inflating: dataset/s18/9.pgm
#    creating: dataset/s19/
#   inflating: dataset/s19/1.pgm
#   inflating: dataset/s19/10.pgm
#   inflating: dataset/s19/2.pgm
#   inflating: dataset/s19/3.pgm
#   inflating: dataset/s19/4.pgm
#   inflating: dataset/s19/5.pgm
#   inflating: dataset/s19/6.pgm
#   inflating: dataset/s19/7.pgm
#   inflating: dataset/s19/8.pgm
#   inflating: dataset/s19/9.pgm
#   inflating: dataset/s1/1.pgm
#   inflating: dataset/s1/10.pgm
#   inflating: dataset/s1/2.pgm
#   inflating: dataset/s1/3.pgm
#   inflating: dataset/s1/4.pgm
#   inflating: dataset/s1/5.pgm
#   inflating: dataset/s1/6.pgm
#   inflating: dataset/s1/7.pgm
#   inflating: dataset/s1/8.pgm
#   inflating: dataset/s1/9.pgm
#    creating: dataset/s2/
#    creating: dataset/s20/
#   inflating: dataset/s20/1.pgm
#   inflating: dataset/s20/10.pgm
#   inflating: dataset/s20/2.pgm
#   inflating: dataset/s20/3.pgm
#   inflating: dataset/s20/4.pgm
#   inflating: dataset/s20/5.pgm
#   inflating: dataset/s20/6.pgm
#   inflating: dataset/s20/7.pgm
#   inflating: dataset/s20/8.pgm
#   inflating: dataset/s20/9.pgm
#    creating: dataset/s21/
#   inflating: dataset/s21/1.pgm
#   inflating: dataset/s21/10.pgm
#   inflating: dataset/s21/2.pgm
#   inflating: dataset/s21/3.pgm
#   inflating: dataset/s21/4.pgm
#   inflating: dataset/s21/5.pgm
#   inflating: dataset/s21/6.pgm
#   inflating: dataset/s21/7.pgm
#   inflating: dataset/s21/8.pgm
#   inflating: dataset/s21/9.pgm
#    creating: dataset/s22/
#   inflating: dataset/s22/1.pgm
#   inflating: dataset/s22/10.pgm
#   inflating: dataset/s22/2.pgm
#   inflating: dataset/s22/3.pgm
#   inflating: dataset/s22/4.pgm
#   inflating: dataset/s22/5.pgm
#   inflating: dataset/s22/6.pgm
#   inflating: dataset/s22/7.pgm
#   inflating: dataset/s22/8.pgm
#   inflating: dataset/s22/9.pgm
#    creating: dataset/s23/
#   inflating: dataset/s23/1.pgm
#   inflating: dataset/s23/10.pgm
#   inflating: dataset/s23/2.pgm
#   inflating: dataset/s23/3.pgm
#   inflating: dataset/s23/4.pgm
#   inflating: dataset/s23/5.pgm
#   inflating: dataset/s23/6.pgm
#   inflating: dataset/s23/7.pgm
#   inflating: dataset/s23/8.pgm
#   inflating: dataset/s23/9.pgm
#    creating: dataset/s24/
#   inflating: dataset/s24/1.pgm
#   inflating: dataset/s24/10.pgm
#   inflating: dataset/s24/2.pgm
#   inflating: dataset/s24/3.pgm
#   inflating: dataset/s24/4.pgm
#   inflating: dataset/s24/5.pgm
#   inflating: dataset/s24/6.pgm
#   inflating: dataset/s24/7.pgm
#   inflating: dataset/s24/8.pgm
#   inflating: dataset/s24/9.pgm
#    creating: dataset/s25/
#   inflating: dataset/s25/1.pgm
#   inflating: dataset/s25/10.pgm
#   inflating: dataset/s25/2.pgm
#   inflating: dataset/s25/3.pgm
#   inflating: dataset/s25/4.pgm
#   inflating: dataset/s25/5.pgm
#   inflating: dataset/s25/6.pgm
#   inflating: dataset/s25/7.pgm
#   inflating: dataset/s25/8.pgm
#   inflating: dataset/s25/9.pgm
#    creating: dataset/s26/
#   inflating: dataset/s26/1.pgm
#   inflating: dataset/s26/10.pgm
#   inflating: dataset/s26/2.pgm
#   inflating: dataset/s26/3.pgm
#   inflating: dataset/s26/4.pgm
#   inflating: dataset/s26/5.pgm
#   inflating: dataset/s26/6.pgm
#   inflating: dataset/s26/7.pgm
#   inflating: dataset/s26/8.pgm
#   inflating: dataset/s26/9.pgm
#    creating: dataset/s27/
#   inflating: dataset/s27/1.pgm
#   inflating: dataset/s27/10.pgm
#   inflating: dataset/s27/2.pgm
#   inflating: dataset/s27/3.pgm
#   inflating: dataset/s27/4.pgm
#   inflating: dataset/s27/5.pgm
#   inflating: dataset/s27/6.pgm
#   inflating: dataset/s27/7.pgm
#   inflating: dataset/s27/8.pgm
#   inflating: dataset/s27/9.pgm
#    creating: dataset/s28/
#   inflating: dataset/s28/1.pgm
#   inflating: dataset/s28/10.pgm
#   inflating: dataset/s28/2.pgm
#   inflating: dataset/s28/3.pgm
#   inflating: dataset/s28/4.pgm
#   inflating: dataset/s28/5.pgm
#   inflating: dataset/s28/6.pgm
#   inflating: dataset/s28/7.pgm
#   inflating: dataset/s28/8.pgm
#   inflating: dataset/s28/9.pgm
#    creating: dataset/s29/
#   inflating: dataset/s29/1.pgm
#   inflating: dataset/s29/10.pgm
#   inflating: dataset/s29/2.pgm
#   inflating: dataset/s29/3.pgm
#   inflating: dataset/s29/4.pgm
#   inflating: dataset/s29/5.pgm
#   inflating: dataset/s29/6.pgm
#   inflating: dataset/s29/7.pgm
#   inflating: dataset/s29/8.pgm
#   inflating: dataset/s29/9.pgm
#   inflating: dataset/s2/1.pgm
#   inflating: dataset/s2/10.pgm
#   inflating: dataset/s2/2.pgm
#   inflating: dataset/s2/3.pgm
#   inflating: dataset/s2/4.pgm
#   inflating: dataset/s2/5.pgm
#   inflating: dataset/s2/6.pgm
#   inflating: dataset/s2/7.pgm
#   inflating: dataset/s2/8.pgm
#   inflating: dataset/s2/9.pgm
#    creating: dataset/s3/
#    creating: dataset/s30/
#   inflating: dataset/s30/1.pgm
#   inflating: dataset/s30/10.pgm
#   inflating: dataset/s30/2.pgm
#   inflating: dataset/s30/3.pgm
#   inflating: dataset/s30/4.pgm
#   inflating: dataset/s30/5.pgm
#   inflating: dataset/s30/6.pgm
#   inflating: dataset/s30/7.pgm
#   inflating: dataset/s30/8.pgm
#   inflating: dataset/s30/9.pgm
#    creating: dataset/s31/
#   inflating: dataset/s31/1.pgm
#   inflating: dataset/s31/10.pgm
#   inflating: dataset/s31/2.pgm
#   inflating: dataset/s31/3.pgm
#   inflating: dataset/s31/4.pgm
#   inflating: dataset/s31/5.pgm
#   inflating: dataset/s31/6.pgm
#   inflating: dataset/s31/7.pgm
#   inflating: dataset/s31/8.pgm
#   inflating: dataset/s31/9.pgm
#    creating: dataset/s32/
#   inflating: dataset/s32/1.pgm
#   inflating: dataset/s32/10.pgm
#   inflating: dataset/s32/2.pgm
#   inflating: dataset/s32/3.pgm
#   inflating: dataset/s32/4.pgm
#   inflating: dataset/s32/5.pgm
#   inflating: dataset/s32/6.pgm
#   inflating: dataset/s32/7.pgm
#   inflating: dataset/s32/8.pgm
#   inflating: dataset/s32/9.pgm
#    creating: dataset/s33/
#   inflating: dataset/s33/1.pgm
#   inflating: dataset/s33/10.pgm
#   inflating: dataset/s33/2.pgm
#   inflating: dataset/s33/3.pgm
#   inflating: dataset/s33/4.pgm
#   inflating: dataset/s33/5.pgm
#   inflating: dataset/s33/6.pgm
#   inflating: dataset/s33/7.pgm
#   inflating: dataset/s33/8.pgm
#   inflating: dataset/s33/9.pgm
#    creating: dataset/s34/
#   inflating: dataset/s34/1.pgm
#   inflating: dataset/s34/10.pgm
#   inflating: dataset/s34/2.pgm
#   inflating: dataset/s34/3.pgm
#   inflating: dataset/s34/4.pgm
#   inflating: dataset/s34/5.pgm
#   inflating: dataset/s34/6.pgm
#   inflating: dataset/s34/7.pgm
#   inflating: dataset/s34/8.pgm
#   inflating: dataset/s34/9.pgm
#    creating: dataset/s35/
#   inflating: dataset/s35/1.pgm
#   inflating: dataset/s35/10.pgm
#   inflating: dataset/s35/2.pgm
#   inflating: dataset/s35/3.pgm
#   inflating: dataset/s35/4.pgm
#   inflating: dataset/s35/5.pgm
#   inflating: dataset/s35/6.pgm
#   inflating: dataset/s35/7.pgm
#   inflating: dataset/s35/8.pgm
#   inflating: dataset/s35/9.pgm
#    creating: dataset/s36/
#   inflating: dataset/s36/1.pgm
#   inflating: dataset/s36/10.pgm
#   inflating: dataset/s36/2.pgm
#   inflating: dataset/s36/3.pgm
#   inflating: dataset/s36/4.pgm
#   inflating: dataset/s36/5.pgm
#   inflating: dataset/s36/6.pgm
#   inflating: dataset/s36/7.pgm
#   inflating: dataset/s36/8.pgm
#   inflating: dataset/s36/9.pgm
#    creating: dataset/s37/
#   inflating: dataset/s37/1.pgm
#   inflating: dataset/s37/10.pgm
#   inflating: dataset/s37/2.pgm
#   inflating: dataset/s37/3.pgm
#   inflating: dataset/s37/4.pgm
#   inflating: dataset/s37/5.pgm
#   inflating: dataset/s37/6.pgm
#   inflating: dataset/s37/7.pgm
#   inflating: dataset/s37/8.pgm
#   inflating: dataset/s37/9.pgm
#   inflating: dataset/s3/1.pgm
#   inflating: dataset/s3/10.pgm
#   inflating: dataset/s3/2.pgm
#   inflating: dataset/s3/3.pgm
#   inflating: dataset/s3/4.pgm
#   inflating: dataset/s3/5.pgm
#   inflating: dataset/s3/6.pgm
#   inflating: dataset/s3/7.pgm
#   inflating: dataset/s3/8.pgm
#   inflating: dataset/s3/9.pgm
#    creating: dataset/s4/
#   inflating: dataset/s4/1.pgm
#   inflating: dataset/s4/10.pgm
#   inflating: dataset/s4/2.pgm
#   inflating: dataset/s4/3.pgm
#   inflating: dataset/s4/4.pgm
#   inflating: dataset/s4/5.pgm
#   inflating: dataset/s4/6.pgm
#   inflating: dataset/s4/7.pgm
#   inflating: dataset/s4/8.pgm
#   inflating: dataset/s4/9.pgm
#    creating: dataset/s5/
#   inflating: dataset/s5/1.pgm
#   inflating: dataset/s5/10.pgm
#   inflating: dataset/s5/2.pgm
#   inflating: dataset/s5/3.pgm
#   inflating: dataset/s5/4.pgm
#   inflating: dataset/s5/5.pgm
#   inflating: dataset/s5/6.pgm
#   inflating: dataset/s5/7.pgm
#   inflating: dataset/s5/8.pgm
#   inflating: dataset/s5/9.pgm
#    creating: dataset/s6/
#   inflating: dataset/s6/1.pgm
#   inflating: dataset/s6/10.pgm
#   inflating: dataset/s6/2.pgm
#   inflating: dataset/s6/3.pgm
#   inflating: dataset/s6/4.pgm
#   inflating: dataset/s6/5.pgm
#   inflating: dataset/s6/6.pgm
#   inflating: dataset/s6/7.pgm
#   inflating: dataset/s6/8.pgm
#   inflating: dataset/s6/9.pgm
#    creating: dataset/s7/
#   inflating: dataset/s7/1.pgm
#   inflating: dataset/s7/10.pgm
#   inflating: dataset/s7/2.pgm
#   inflating: dataset/s7/3.pgm
#   inflating: dataset/s7/4.pgm
#   inflating: dataset/s7/5.pgm
#   inflating: dataset/s7/6.pgm
#   inflating: dataset/s7/7.pgm
#   inflating: dataset/s7/8.pgm
#   inflating: dataset/s7/9.pgm
#    creating: dataset/s8/
#   inflating: dataset/s8/1.pgm
#   inflating: dataset/s8/10.pgm
#   inflating: dataset/s8/2.pgm
#   inflating: dataset/s8/3.pgm
#   inflating: dataset/s8/4.pgm
#   inflating: dataset/s8/5.pgm
#   inflating: dataset/s8/6.pgm
#   inflating: dataset/s8/7.pgm
#   inflating: dataset/s8/8.pgm
#   inflating: dataset/s8/9.pgm
#    creating: dataset/s9/
#   inflating: dataset/s9/1.pgm
#   inflating: dataset/s9/10.pgm
#   inflating: dataset/s9/2.pgm
#   inflating: dataset/s9/3.pgm
#   inflating: dataset/s9/4.pgm
#   inflating: dataset/s9/5.pgm
#   inflating: dataset/s9/6.pgm
#   inflating: dataset/s9/7.pgm
#   inflating: dataset/s9/8.pgm
#   inflating: dataset/s9/9.pgm
#   inflating: FaceDetection.bmp

# %%
# %matplotlib inline
from skimage.io import imread
from scipy import signal,ndimage
import numpy as np
import time
import scipy.io as sio
from matplotlib.pyplot import imshow,show,figure
import skimage.transform as tf
import IPython
import scipy
from sys import getsizeof

def make_grid(image_list,rows=5):
    cols = len(image_list)//rows
    row_image_list = []
    for c in range(cols):
        col_image_list = []
        for r in range(rows):
            col_image_list.append(image_list[c*rows+r])
        col_image = np.concatenate(col_image_list,axis=0)
        row_image_list.append(col_image)
    return np.concatenate(row_image_list,axis=1)

# %% [markdown]
# # Load images
#
# We use the AT&T dataset, which consists of 40 people with 10 experssions each. We split the dataset into two parts, training images and test images. The training images will be used to extract the eigenfaces, which are then used to compress test images.
#
# **First, we load the training data.** Here we take 5 expressions of 20 people as training set.

# %%
train_person_ids = np.arange(1,21)
train_expression_ids = np.arange(1,6)
train_image_list = []
for pid in train_person_ids:
    for eid in train_expression_ids:
        image = imread('dataset/s%d/%d.pgm'%(pid,eid))/255.
        image = tf.rescale(image,0.6)
        h,w = image.shape
        train_image_list.append(image)

train_image_collage = make_grid(train_image_list,rows=5)
imshow(train_image_collage,cmap='gray')

# %% [markdown]
# **Then we load the test images.** To see if the method can deal with unseen people and unseen expressions, we test with the rest 5 expressions of the rest 20 people.

# %%
test_person_ids = np.arange(21,38)
test_expression_ids = np.arange(6,11)
test_image_list = []
for pid in test_person_ids:
    for eid in test_expression_ids:
        image = imread('dataset/s%d/%d.pgm'%(pid,eid))/255.
        image = tf.rescale(image,0.6)
        h,w = image.shape
        test_image_list.append(image)
        
test_image_collage = make_grid(test_image_list,rows=5)
imshow(test_image_collage,cmap='gray')

# %% [markdown]
# ## Part A: Image Compression
#
# In part A, we will use PCA to compress face images. For convenience we reshape the N training images into vectors of length $D = Height\times Width$ and concatenate all vectors to form a $N \times D$ matrix $X$.

# %%
image_vectors = [image.flatten() for image in train_image_list]
X = np.stack(image_vectors,axis=1)
X.shape
# Out:
# (3685, 100)

# %% [markdown]
# **Compute the mean and covariance of images.** The mean of images $\mu$ is a vector of length $D$ and can be visualized as an image. The covariance $\Sigma$ is a $D \times D$ matrix. You can use `numpy.mean()` and `numpy.cov()` for the computation.

# %%
mean = np.mean(X, axis=1)
covariance = np.cov(X)

imshow(mean.reshape(h,w),cmap='gray')
# Out:
# (3685, 3685)

# %% [markdown]
# **Compute eigenfaces.** Eigenfaces are the eigenvectors correponding to k-largest eigenvalues of covariance matrix. You can use `scipy.sparse.linalg.eigs(mat,k)` to compute $k$ largest eigenvalues of $mat$ and corresponding eigenvectors $[v_1...v_k]$ . Note that this function returns complex valued results, which needs to be converted to real numbers using `numpy.real()`.

# %%
num_eigenvectors = 100
eigenvalues, eigenvectors = scipy.sparse.linalg.eigs(covariance, num_eigenvectors)
eigenvectors = eigenvectors.real


# for eigenvector in eigenvectors.T:
#     imshow(eigenvector.reshape(h,w),cmap='gray')    
#     IPython.display.clear_output(True)
#     show()
eigenvectors.shape
# Out:
# (3685, 100)

# %% [markdown]
# **Now we can use the computed eigenfaces to compress images.** Face images can be approximated by linear combinations of eigenfaces $x=\mu + \alpha_1v_1 + \alpha_2v_2 + .... + \alpha_kv_k$. Therefore, we can use the weights $[\alpha_1 ... \alpha_k]$ to record a image, instead of saving all pixels values. Each weight $\alpha_i$ is the projection of the normalized image $\tilde{x} = x-\mu$ onto the corresponding eigenface $v_i$, which can be computed by dot product $\alpha_i = \tilde{x} \cdot v_i$.
#
# To recover a image from its compression we can use  $x=\mu + \alpha_1v_1 + \alpha_2v_2 + .... + \alpha_kv_k$.
#
#
# **Complete the lines below to compress a image into a $k$ dimensional vector.**
#
# **Q:** Compress training images and test images. On which set the method works better? Why?
#
# **Q:** Compress image with different number of eigenfaces. What's the influence of $k$?
#
# **Q:** Considering that we want to reduce data size, what is the maximum value of $k$?

# %%
error_images = []
for image in train_image_list[:]:
    normalized = image.flatten() - mean
    compressed_image =  eigenvectors.T @ normalized
    decompressed_image = eigenvectors @ compressed_image + mean
    
    error_image = np.abs(decompressed_image-image.flatten())
    error_images.append(error_image)

    imshow(np.concatenate([image.reshape(h,w),\
                          decompressed_image.reshape(h,w),\
                          error_image.reshape(h,w)],axis=-1),cmap='gray')

    IPython.display.clear_output(True)
    show()
    
print('Size before compression: %d Bytes'%image.nbytes)
print('Size after compression: %d Bytes'%compressed_image.nbytes)
print('Size diff: %.2f'%(100.0* compressed_image.nbytes / image.nbytes - 100) + "%")
           
error_images = np.stack(error_images,0)
ssd_error = (error_images**2).sum(-1).mean()
print(ssd_error)
# Out:
# Size before compression: 29480 Bytes
# Size after compression: 2000 Bytes
# Size diff: -93.22%
# 7.436579525909631e-27

# %% [markdown]
# # Part B: Face Detection with PCA
# **In this part we will use PCA to detect faces.** In previous part, we have implemented a compressor for face images. Since the eigenvectors are extracted from faces images, we can expect that such a compressor would fail on other images, leading to erroneous decompression. This fact can be used for face detection.
#
# You are given an image with a face and your task is to find the location (x coordinate) of the face.
# Try to compress and then decompress each part of the image using the method in part A, and then compute the SSD error. Based on the SSD error, find the localtion (x coordinate) where the face is located.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

image = imread('FaceDetection.bmp')[:h,:]/255.
h_,w_ = image.shape

errors = []

# iterate over each part of the image
for x in range(w_-w):
    image_crop = image[:,x:x+w].flatten()

    normalized = image_crop.flatten() - mean
    compressed_image =  eigenvectors.T @ normalized
    decompressed_image = eigenvectors @ compressed_image + mean
    
    error = np.sum((decompressed_image-image_crop.flatten())**2)
    
    errors.append(error)
    
    fig, ax = plt.subplots(2,1)
    rect = patches.Rectangle((x,0),w,h,linewidth=3,edgecolor='r',facecolor='none')
    ax[0].imshow(image,cmap='gray')
    ax[0].add_patch(rect)
    ax[1].plot(np.arange(x+1)+w//2,np.array(errors))
    ax[1].set_xlim([0,w_])
    IPython.display.clear_output(True)
    show()

x_best = np.argmin(errors)
fig, ax = plt.subplots(2,1)
rect = patches.Rectangle((x_best,0),w,h,linewidth=3,edgecolor='g',facecolor='none')

ax[0].imshow(image,cmap='gray')
ax[0].add_patch(rect)
ax[1].plot(np.arange(x+1)+w//2,np.array(errors))
ax[1].set_xlim([0,w_])
IPython.display.clear_output(True)
show()

# %% [markdown]
# # Part C: Exam question

# %% [markdown]
# ![alt](exam_question.png)
